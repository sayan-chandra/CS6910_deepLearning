# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/ MyDrive/
# Out:
# [Errno 2] No such file or directory: 'drive/ MyDrive/'
# /content/drive/ MyDrive/git_cs6910

# %%
# %cd git_cs6910/
#!git init
# Out:
# [Errno 2] No such file or directory: 'git_cs6910/'
# /content/drive/ MyDrive/git_cs6910

# %%
#!git remote -v
#!pwd
#!ls
# Out:
# /content

# %%
# !git config --global user.email "shaanchandra69@gmail.com"
# !git config --global user.name "sayan-chandra"

# %%
#!git remote add origin https://github.com/sayan-chandra/CS6910_deepLearning.git

# %%
#!git remote set-url origin https://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:x-oauth-basic@github.com/sayan-chandra/CS6910_deepLearning.git

# %%
# !git add .
# !git commit -m "added readme.md and some more code changes"
# Out:
# [master 353226e] added readme.md and some more code changes
#  3 files changed, 100 insertions(+), 90 deletions(-)
#  rewrite Assignment_2(cnn)/PART_A/ASSGN_2(Part-A_Ques-4(a_b_c).ipynb (78%)

# %%
# !git push origin master --force
# Out:
# Counting objects: 104, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (104/104), done.
# Writing objects: 100% (104/104), 3.13 MiB | 5.19 MiB/s, done.
# Total 104 (delta 55), reused 0 (delta 0)
# remote: Resolving deltas: 100% (55/55), done.
# To https://github.com/sayan-chandra/CS6910_deepLearning.git
#  + 6692bb3...353226e master -> master (forced update)
