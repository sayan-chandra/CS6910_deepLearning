# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/ MyDrive/
# Out:
# [Errno 2] No such file or directory: 'drive/ MyDrive/'
# /content/drive/ MyDrive/git_cs6910

# %%
# %cd git_cs6910/
#!git init
# Out:
# [Errno 2] No such file or directory: 'git_cs6910/'
# /content/drive/ MyDrive/git_cs6910

# %%
#!git remote -v
#!pwd
#!ls
# Out:
# /content/drive/My Drive/git_cs6910

# %%
# !git config --global user.email "shaanchandra69@gmail.com"
# !git config --global user.name "sayan-chandra"

# %%
#!git remote add origin https://github.com/sayan-chandra/CS6910_deepLearning.git

# %%
#!git remote set-url origin https://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:x-oauth-basic@github.com/sayan-chandra/CS6910_deepLearning.git

# %%
# !git add .
# !git commit -m "added videos in part c folder"
# Out:
# [master 03bcb8c] added videos in part c folder
#  3 files changed, 1 insertion(+), 1 deletion(-)
#  rewrite Assignment_1(ffnn)/git.ipynb (93%)
#  create mode 100644 Assignment_2(cnn)/PART_C/Face_Mask_detection_using_YOLOv3.mp4
#  create mode 100644 Assignment_2(cnn)/PART_C/person_dog_car_detection.mp4

# %%
# !git push origin master
# Out:
# Counting objects: 8, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 48.89 MiB | 12.85 MiB/s, done.
# Total 8 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/sayan-chandra/CS6910_deepLearning.git
#    353226e..03bcb8c  master -> master
