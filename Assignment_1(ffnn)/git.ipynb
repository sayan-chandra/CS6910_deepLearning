# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/ MyDrive/
# Out:
# /content/drive/ MyDrive

# %%
# %cd git_cs6910/
#!git init
# Out:
# /content/drive/ MyDrive/git_cs6910

# %%
#!git remote -v
#!pwd
#!ls
# Out:
# /content

# %%
# !git config --global user.email "shaanchandra69@gmail.com"
# !git config --global user.name "sayan-chandra"

# %%
#!git remote add origin https://github.com/sayan-chandra/CS6910_deepLearning.git

# %%
#!git remote set-url origin https://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:x-oauth-basic@github.com/sayan-chandra/CS6910_deepLearning.git

# %%
# !git add .
# !git commit -m "added readme and "
# Out:
# [master 23c70be] assgn 2 part A question 5 guided backprop
#  3 files changed, 3 insertions(+), 2 deletions(-)
#  rewrite Assignment_1(ffnn)/git.ipynb (92%)
#  rewrite Assignment_2(cnn)/PART_A/ASSGN_2(Part-A_Ques-4(a_b_c).ipynb (78%)
#  create mode 100644 Assignment_2(cnn)/PART_A/ASSGN_2(Part-A_Ques-5).ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 8, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 1.51 MiB | 4.61 MiB/s, done.
# Total 8 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/sayan-chandra/CS6910_deepLearning.git
#    d85ad52..23c70be  master -> master
