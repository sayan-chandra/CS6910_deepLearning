# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/ MyDrive/
# Out:
# /content/drive/ MyDrive

# %%
# %cd git_cs6910/
#!git init
# Out:
# /content/drive/ MyDrive/git_cs6910

# %%
#!git remote -v
#!pwd
#!ls
# Out:
# /content

# %%
# !git config --global user.email "shaanchandra69@gmail.com"
# !git config --global user.name "sayan-chandra"

# %%
#!git remote add origin https://github.com/sayan-chandra/CS6910_deepLearning.git

# %%
#!git remote set-url origin https://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:x-oauth-basic@github.com/sayan-chandra/CS6910_deepLearning.git

# %%
# !git add .
# !git commit -m "added readme and some code changes"
# Out:
# [master a32289e] added readme and some code changes
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin master --force
# Out:
# Counting objects: 86, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (86/86), done.
# Writing objects: 100% (86/86), 3.12 MiB | 5.33 MiB/s, done.
# Total 86 (delta 45), reused 0 (delta 0)
# remote: Resolving deltas: 100% (45/45), done.
# To https://github.com/sayan-chandra/CS6910_deepLearning.git
#  + 47390c4...a32289e master -> master (forced update)

# %%
# !curl -u "sayan-chandra" https://api.github.com/repos/sayan-chandra/CS6910_deepLearning/events
# Out:
# Enter host password for user 'sayan-chandra':
# {
#   "message": "Not Found",
#   "documentation_url": "https://docs.github.com/rest/reference/activity#list-repository-events"
# }
