# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/ MyDrive/
# Out:
# /content/drive/ MyDrive

# %%
#%cd git_cs6910/
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/git_cs6910/.git/

# %%
#!git remote -v
#!pwd
#!ls
# Out:
# /content/drive/My Drive/git_cs6910
# 'Assignment_1(ffnn)'  'Assignment_2(cnn)'

# %%
# !git config --global user.email "shaanchandra69@gmail.com"
# !git config --global user.name "sayan-chandra"

# %%
#!git remote add origin https://github.com/sayan-chandra/CS6910_deepLearning.git

# %%
#!git remote set-url origin https://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:x-oauth-basic@github.com/sayan-chandra/CS6910_deepLearning.git

# %%
# !git add .
# !git commit -m "making cnn model as part-A-ques-1 says"
# Out:
# [master (root-commit) aeeba42] making cnn model as part-A-ques-1 says
#  7 files changed, 680 insertions(+)
#  create mode 100644 Assignment_1(ffnn)/Assgn_1 Question_(3+4).ipynb
#  create mode 100644 Assignment_1(ffnn)/Assgn_1 Question_1.ipynb
#  create mode 100644 Assignment_1(ffnn)/Assgn_1 Question_2.ipynb
#  create mode 100644 Assignment_1(ffnn)/Assgn_1Question_8.ipynb
#  create mode 100644 Assignment_1(ffnn)/git.ipynb
#  create mode 100644 Assignment_1(ffnn)/readme.md
#  create mode 100644 Assignment_2(cnn)/ASSGN_2(Part-A_Ques-1).ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 11, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (11/11), 107.04 KiB | 2.89 MiB/s, done.
# Total 11 (delta 0), reused 0 (delta 0)
# To https://github.com/sayan-chandra/CS6910_deepLearning.git
#  + ad1b0c3...aeeba42 master -> master (forced update)
