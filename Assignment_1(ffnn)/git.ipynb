# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/ MyDrive/
# Out:
# /content/drive/ MyDrive

# %%
# %cd git_cs6910/
#!git init
# Out:
# /content/drive/ MyDrive/git_cs6910

# %%
#!git remote -v
#!pwd
#!ls

# %%
# !git config --global user.email "shaanchandra69@gmail.com"
# !git config --global user.name "sayan-chandra"

# %%
#!git remote add origin https://github.com/sayan-chandra/CS6910_deepLearning.git

# %%
#!git remote set-url origin https://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:x-oauth-basic@github.com/sayan-chandra/CS6910_deepLearning.git

# %%
# !git add .
# !git commit -m "assgn 3 Q2 adding"
# Out:
# [master cb37207] assgn 3 Q1 adding
#  4 files changed, 3 insertions(+), 2 deletions(-)
#  rewrite Assignment_1(ffnn)/git.ipynb (97%)
#  rewrite Assignment_2(cnn)/PART_A/ASSGN_2(Part-A_Ques-5).ipynb (99%)
#  create mode 100644 Assignment_2(cnn)/PART_B/DL_assignment_2_CS20M057.pdf
#  create mode 100644 Assignment_3(rnn)/ASSGN_3_Q1.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 11, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (11/11), 87.55 KiB | 7.96 MiB/s, done.
# Total 11 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/sayan-chandra/CS6910_deepLearning.git
#    0b9be56..cb37207  master -> master
