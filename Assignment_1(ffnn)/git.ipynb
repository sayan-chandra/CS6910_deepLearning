# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/ MyDrive/
# Out:
# /content/drive/ MyDrive

# %%
#%cd git_cs6910/
#!git init
# Out:
# /content/drive/ MyDrive/git_cs6910

# %%
#!git remote -v
#!pwd
#!ls
# Out:
# /content

# %%
# !git config --global user.email "shaanchandra69@gmail.com"
# !git config --global user.name "sayan-chandra"

# %%
#!git remote add origin https://github.com/sayan-chandra/CS6910_deepLearning.git

# %%
#!git remote set-url origin https://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:x-oauth-basic@github.com/sayan-chandra/CS6910_deepLearning.git

# %%
# !git add .
# !git commit -m "initialising model and incorporated code for GPU "
# Out:
# [master 579d087] loading data and splitting into train test val part-A-ques-2 says
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite Assignment_1(ffnn)/git.ipynb (82%)
#  rewrite Assignment_2(cnn)/ASSGN_2(Part-A_Ques-2) (91%)

# %%
# !git push origin master
# Out:
# Counting objects: 12, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (12/12), 131.78 KiB | 4.39 MiB/s, done.
# Total 12 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 2 local objects.
# To https://github.com/sayan-chandra/CS6910_deepLearning.git
#    9629a36..579d087  master -> master
