# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/ MyDrive/
# Out:
# /content/drive/ MyDrive

# %%
# %cd git_cs6910/
#!git init
# Out:
# /content/drive/ MyDrive/git_cs6910

# %%
#!git remote -v
#!pwd
#!ls
# Out:
# /content

# %%
# !git config --global user.email "shaanchandra69@gmail.com"
# !git config --global user.name "sayan-chandra"

# %%
#!git remote add origin https://github.com/sayan-chandra/CS6910_deepLearning.git

# %%
#!git remote set-url origin https://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:x-oauth-basic@github.com/sayan-chandra/CS6910_deepLearning.git

# %%
# !git add .
# !git commit -m "assgn 2 part A question 5 guided backprop, "
# Out:
# [master d85ad52] assgn 2 question 4 a,b,c with images
#  5 files changed, 3 insertions(+), 2 deletions(-)
#  rewrite Assignment_1(ffnn)/git.ipynb (68%)
#  rename Assignment_2(cnn)/{ => PART_A}/ASSGN_2(Part-A_Ques-1).ipynb (100%)
#  rename Assignment_2(cnn)/{ => PART_A}/ASSGN_2(Part-A_Ques-2).ipynb (100%)
#  create mode 100644 Assignment_2(cnn)/PART_A/ASSGN_2(Part-A_Ques-4(a_b_c).ipynb
#  rename Assignment_2(cnn)/{ => PART_B}/ASSGN_2(Part-B_Ques-1).ipynb (62%)

# %%
# !git push origin master
# Out:
# Counting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 1.37 MiB | 3.63 MiB/s, done.
# Total 9 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/sayan-chandra/CS6910_deepLearning.git
#    adbb725..d85ad52  master -> master
